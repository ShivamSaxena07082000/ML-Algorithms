# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import plotly.express as px
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# ### Load Data Set

# %%
df=pd.read_csv('https://raw.githubusercontent.com/digipodium/Datasets/main/oil_dataset.csv')

# %%
df
# Out:
#      Mendacium     Depth       Price
# 0        3.359  1722.533   74.048691
# 1        1.348  2062.571   83.321907
# 2        0.418  2013.507   82.748964
# 3        8.193  1420.607   84.760494
# 4        5.210   951.957   54.588671
# ..         ...       ...         ...
# 995      1.755   247.752   51.477497
# 996      2.771  1609.462   73.971975
# 997     11.559  1943.008  123.883064
# 998      8.645  2250.942  116.879069
# 999      7.523  2291.386  100.888292
#
# [1000 rows x 3 columns]

# %%
df.plot(x='Mendacium',y='Depth',kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
px.scatter_3d(df,x='Mendacium',y='Depth',z='Price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/formatters.py?line=918'>919</a> method = get_real_method(obj, self.print_method)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/formatters.py?line=919'>920</a> if method is not None:
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/formatters.py?line=920'>921</a>     method()
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/formatters.py?line=921'>922</a>     return True
#
# ...

# %%
x=df[['Mendacium','Depth']]
y=df['Price']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
model=DecisionTreeRegressor(max_depth=6)
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(max_depth=6)

# %%
print(model.score(xtest,ytest)*100)
# Out:
# 95.40038205414734

# %%
pred=model.predict(x)

# %%
print("Mean Absolute Eroor:",mean_absolute_error(y,pred))
print("Mean_squared_error:",mean_squared_error(y,pred))
# Out:
# Mean Absolute Eroor: 4.80162522829298
# Mean_squared_error: 35.72347639397558
